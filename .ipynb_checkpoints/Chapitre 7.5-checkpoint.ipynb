# %%
import numpy as np
import matplotlib.pylab as plt
from matplotlib.patches import Polygon
from matplotlib.collections import PolyCollection
import plotly.offline as pyo
import plotly.graph_objs as go
from Ch7Functions import *
from IPython.display import display, Latex
pyo.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %% [markdown]
# ## Chapitre 7.5 – Représentations géométriques des déterminants
#
# Soit $A=(a_{ij})\in M_{2 \times 2}(\mathbb{R})$, le déterminant de $A$ est l'aire du parallélogramme crée par les deux vecteurs de $A$.
#
# Dans la prochaine partie, vous pouvez changer les paramètres de $A$ et voir comment le parallélogramme va changer.

# %%
A = [[4.5, -1.5], 
     [3.3, 6.4]]

plotDeterminant2D(A)
# Out:
# L'aire est: 33.75

# %% [markdown]
# Soit $A=(a_{ij})\in M_{3 \times 3}(\mathbb{R})$, le déterminant de $A$ est le volume du parallélépipède crée par les trois vecteurs de $A$.

# %%
A = [[-3, 1, 5],
    [2, -1, 3],
    [1, -5, -1]]

plotDeterminant3D(A)
# Out:
# <div>
#
#
#             <div id="2384d2af-62a6-4bbb-807b-24c3ff31b021" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2384d2af-62a6-4bbb-807b-24c3ff31b021")) {
#                     Plotly.newPlot(
#                         '2384d2af-62a6-4bbb-807b-24c3ff31b021',
# ...
